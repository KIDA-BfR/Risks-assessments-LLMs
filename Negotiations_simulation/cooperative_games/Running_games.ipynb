# %%
# Looping through the script
from time import sleep
from IPython.display import display, clear_output


num_runs = 10  # replace with your desired number of runs, 10 used for  the Hunting example
API_key='You need to specify your API_key'# You can refer to the preliminary negotiations instructions on API key establishment

# Loop to execute the cell the predefined number of times
for i in range(num_runs):


    # Run the cell that executes the python script
    display(f"Run {i + 1} of {num_runs}")
    # !python /content/Hunting_hackaton_BfR_final/LLM-Deliberation/cooperative_games/main_cooperative.py --api_key API_key --output_dir '/content/Hunting_hackaton_BfR_final/LLM-Deliberation/output_Hunting/GPT4o-Hunter' --rounds 12 --window_size 6 --votes_interval 6 --initial_prompts_file initial_prompts_base_Hunting/initial_prompts_hunting_Hunter.txt --initial_deal_file initial_prompts_base_Hunting/initial_deal_Hunter.txt
    #!python /content/Hunting_hackaton_BfR_final/LLM-Deliberation/cooperative_games/main_cooperative.py --api_key API_key --output_dir '/content/Hunting_hackaton_BfR_final/LLM-Deliberation/output_Bt/August_2024' --rounds 12 --window_size 6 --votes_interval 6 --initial_prompts_file initial_prompts_base/initial_prompts.txt --initial_deal_file initial_prompts_base/initial_deal_Consumers.txt
    #!python /content/Hunting_hackaton_BfR_final/LLM-Deliberation/cooperative_games/main_cooperative.py --api_key API_key --output_dir '/content/Hunting_hackaton_BfR_final/LLM-Deliberation/output_Bt/August_2024/Penalties' --rounds 12 --window_size 6 --votes_interval 6 --initial_prompts_file initial_prompts_base/initial_prompts_penalty.txt --initial_deal_file initial_prompts_base/initial_deal_Consumers.txt

    # Optional: Clear the output after each run if you don't want to see all previous outputs
    clear_output(wait=True)

# %%
# !zip -r /content/Hunting_hackaton_BfR_final/LLM-Deliberation/output_Hunting/Results_Hunting_Hunter.zip  # Zipping the outputs

# %%
# Downloading the zipped output
from google.colab import files
files.download("/content/Hunting_hackaton_BfR_final/LLM-Deliberation/output_Hunting/Results_Hunting_Hunter.zip")
